# %%
from kafka import KafkaConsumer

topic_name = 'NewTopic'
consumer = KafkaConsumer(topic_name)
for msg in consumer:
    print (msg)
# Out:
# ConsumerRecord(topic='NewTopic', partition=0, offset=0, timestamp=1702567776340, timestamp_type=0, key=None, value=b'some_message_bytes', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=18, serialized_header_size=-1)
# ConsumerRecord(topic='NewTopic', partition=0, offset=1, timestamp=1702567776340, timestamp_type=0, key=None, value=b'some_message_bytes', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=18, serialized_header_size=-1)
# ConsumerRecord(topic='NewTopic', partition=0, offset=2, timestamp=1702567776340, timestamp_type=0, key=None, value=b'some_message_bytes', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=18, serialized_header_size=-1)
# ConsumerRecord(topic='NewTopic', partition=0, offset=3, timestamp=1702567776340, timestamp_type=0, key=None, value=b'some_message_bytes', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=18, serialized_header_size=-1)
# ...
